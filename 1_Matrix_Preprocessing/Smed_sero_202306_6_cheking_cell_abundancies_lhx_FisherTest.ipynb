# %% [markdown]
# # FISHER TEST

# %% [markdown]
# The aim of this Jupyter Notebook is to evaluate the significant differences in the subset of neuronal cluster abundances between S. mediterranea **heads** and **body** cells using the **Fisher test**.

# %% [markdown]
# # Importing modules and settings

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import math
import seaborn as sns

# %%
from scipy import stats
from Bio import SeqIO
from matplotlib.pyplot import rc_context

# %%
pd.options.display.float_format = '{:,.3f}'.format

# %%
pd.set_option('use_inf_as_na',True)

# %%
umap_cmap = sns.blend_palette(['xkcd:light grey', 'xkcd:indigo'], as_cmap = True)

# %%
sc.settings.verbosity = 4 
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.9.1 anndata==0.9.1 umap==0.5.3 numpy==1.21.5 scipy==1.7.3 pandas==1.4.2 scikit-learn==1.0.2 statsmodels==0.13.2 python-igraph==0.9.11 pynndescent==0.5.7

# %% [markdown]
# # Declaring input and output files

# %%
adata = sc.read_h5ad('./Serotonergic_data_annotated.h5ad')

# %%
adata.obs
# Out:
#                                           sample biological_rep technical_rep  \
# L43_1_AACCATTGGAGACTAGTAACGCTCGA       gfp(RNAi)             B2            T2
# L43_1_CATTCGACGGAGATCGCACGCTGATC       gfp(RNAi)             B2            T2
# L43_1_ACGGAGGCGGTGGAACAATAGGATGA       gfp(RNAi)             B2            T1
# L43_1_GACCTTGATAACGCTCGACAAGACTA       gfp(RNAi)             B2            T2
# L43_1_TTACCTCGACTGGAACAAAGATCGCA  lhx1/5-1(RNAi)             B1            T2
# ...                                          ...            ...           ...
# L43_5_TAACTGGTTAAAGGTACAGAGTTAGC       gfp(RNAi)             B2            T2
# L43_5_GGTACCGGCAGAATCTGATGAAGAGA       gfp(RNAi)             B2            T2
# L43_5_GCCGCAACGACCAGTTCAAGCAGGAA       gfp(RNAi)             B1            T2
# L43_5_CCAGTTCCAATGGAACAAATTGGCTC       gfp(RNAi)             B2            T1
# L43_5_TTCGCCTCCACAAGGAGCAAACATCG  lhx1/5-1(RNAi)             B1            T2
#
#                                  library         sample_bio  \
# L43_1_AACCATTGGAGACTAGTAACGCTCGA    Lib1       gfp(RNAi)_B2
# L43_1_CATTCGACGGAGATCGCACGCTGATC    Lib1       gfp(RNAi)_B2
# L43_1_ACGGAGGCGGTGGAACAATAGGATGA    Lib1       gfp(RNAi)_B2
# L43_1_GACCTTGATAACGCTCGACAAGACTA    Lib1       gfp(RNAi)_B2
# L43_1_TTACCTCGACTGGAACAAAGATCGCA    Lib1  lhx1/5-1(RNAi)_B1
# ...                                  ...                ...
# L43_5_TAACTGGTTAAAGGTACAGAGTTAGC    Lib5       gfp(RNAi)_B2
# L43_5_GGTACCGGCAGAATCTGATGAAGAGA    Lib5       gfp(RNAi)_B2
# L43_5_GCCGCAACGACCAGTTCAAGCAGGAA    Lib5       gfp(RNAi)_B1
# L43_5_CCAGTTCCAATGGAACAAATTGGCTC    Lib5       gfp(RNAi)_B2
# L43_5_TTCGCCTCCACAAGGAGCAAACATCG    Lib5  lhx1/5-1(RNAi)_B1
#
#                                                unique            sample_rep  \
# L43_1_AACCATTGGAGACTAGTAACGCTCGA       gfp(RNAi)_Lib1       gfp(RNAi)_B2_T2
# L43_1_CATTCGACGGAGATCGCACGCTGATC       gfp(RNAi)_Lib1       gfp(RNAi)_B2_T2
# L43_1_ACGGAGGCGGTGGAACAATAGGATGA       gfp(RNAi)_Lib1       gfp(RNAi)_B2_T1
# L43_1_GACCTTGATAACGCTCGACAAGACTA       gfp(RNAi)_Lib1       gfp(RNAi)_B2_T2
# L43_1_TTACCTCGACTGGAACAAAGATCGCA  lhx1/5-1(RNAi)_Lib1  lhx1/5-1(RNAi)_B1_T2
# ...                                               ...                   ...
# L43_5_TAACTGGTTAAAGGTACAGAGTTAGC       gfp(RNAi)_Lib5       gfp(RNAi)_B2_T2
# L43_5_GGTACCGGCAGAATCTGATGAAGAGA       gfp(RNAi)_Lib5       gfp(RNAi)_B2_T2
# L43_5_GCCGCAACGACCAGTTCAAGCAGGAA       gfp(RNAi)_Lib5       gfp(RNAi)_B1_T2
# L43_5_CCAGTTCCAATGGAACAAATTGGCTC       gfp(RNAi)_Lib5       gfp(RNAi)_B2_T1
# L43_5_TTCGCCTCCACAAGGAGCAAACATCG  lhx1/5-1(RNAi)_Lib5  lhx1/5-1(RNAi)_B1_T2
#
#                                                  unique_rep  n_counts  \
# L43_1_AACCATTGGAGACTAGTAACGCTCGA       gfp(RNAi)_B2_T2_Lib1   148.000
# L43_1_CATTCGACGGAGATCGCACGCTGATC       gfp(RNAi)_B2_T2_Lib1   176.000
# L43_1_ACGGAGGCGGTGGAACAATAGGATGA       gfp(RNAi)_B2_T1_Lib1   502.000
# L43_1_GACCTTGATAACGCTCGACAAGACTA       gfp(RNAi)_B2_T2_Lib1   185.000
# L43_1_TTACCTCGACTGGAACAAAGATCGCA  lhx1/5-1(RNAi)_B1_T2_Lib1   180.000
# ...                                                     ...       ...
# L43_5_TAACTGGTTAAAGGTACAGAGTTAGC       gfp(RNAi)_B2_T2_Lib5   411.000
# L43_5_GGTACCGGCAGAATCTGATGAAGAGA       gfp(RNAi)_B2_T2_Lib5   262.000
# L43_5_GCCGCAACGACCAGTTCAAGCAGGAA       gfp(RNAi)_B1_T2_Lib5   110.000
# L43_5_CCAGTTCCAATGGAACAAATTGGCTC       gfp(RNAi)_B2_T1_Lib5   238.000
# L43_5_TTCGCCTCCACAAGGAGCAAACATCG  lhx1/5-1(RNAi)_B1_T2_Lib5   230.000
#
#                                   n_genes  ...  pct_counts_mt  leiden_1  \
# L43_1_AACCATTGGAGACTAGTAACGCTCGA      130  ...          0.000         8
# L43_1_CATTCGACGGAGATCGCACGCTGATC      159  ...          0.000         1
# L43_1_ACGGAGGCGGTGGAACAATAGGATGA      359  ...          0.000         0
# L43_1_GACCTTGATAACGCTCGACAAGACTA      149  ...          0.000         4
# L43_1_TTACCTCGACTGGAACAAAGATCGCA      166  ...          0.000         2
# ...                                   ...  ...            ...       ...
# L43_5_TAACTGGTTAAAGGTACAGAGTTAGC      212  ...          0.000         7
# L43_5_GGTACCGGCAGAATCTGATGAAGAGA      186  ...          0.000         0
# L43_5_GCCGCAACGACCAGTTCAAGCAGGAA      103  ...          0.000         5
# L43_5_CCAGTTCCAATGGAACAAATTGGCTC      201  ...          0.000         1
# L43_5_TTCGCCTCCACAAGGAGCAAACATCG      138  ...          0.000         3
#
#                                   leiden_2  leiden_3 leiden_4  \
# L43_1_AACCATTGGAGACTAGTAACGCTCGA         9         7       25
# L43_1_CATTCGACGGAGATCGCACGCTGATC         1         1        0
# L43_1_ACGGAGGCGGTGGAACAATAGGATGA         0         0        7
# L43_1_GACCTTGATAACGCTCGACAAGACTA         3         9        5
# L43_1_TTACCTCGACTGGAACAAAGATCGCA         6         3        9
# ...                                    ...       ...      ...
# L43_5_TAACTGGTTAAAGGTACAGAGTTAGC        37        26       49
# L43_5_GGTACCGGCAGAATCTGATGAAGAGA         0         5        4
# L43_5_GCCGCAACGACCAGTTCAAGCAGGAA         8         6        3
# L43_5_CCAGTTCCAATGGAACAAATTGGCTC         1         1        0
# L43_5_TTCGCCTCCACAAGGAGCAAACATCG        33        38       43
#
#                                                  ingest_names  \
# L43_1_AACCATTGGAGACTAGTAACGCTCGA    pgrn+ parenchymal cells 1
# L43_1_CATTCGACGGAGATCGCACGCTGATC              chat+ neurons 1
# L43_1_ACGGAGGCGGTGGAACAATAGGATGA                  neoblasts 1
# L43_1_GACCTTGATAACGCTCGACAAGACTA  early epidermal progenitors
# L43_1_TTACCTCGACTGGAACAAAGATCGCA     intestinal and DV muscle
# ...                                                       ...
# L43_5_TAACTGGTTAAAGGTACAGAGTTAGC                    epidermis
# L43_5_GGTACCGGCAGAATCTGATGAAGAGA                  neoblasts 1
# L43_5_GCCGCAACGACCAGTTCAAGCAGGAA    pgrn+ parenchymal cells 2
# L43_5_CCAGTTCCAATGGAACAAATTGGCTC              chat+ neurons 1
# L43_5_TTCGCCTCCACAAGGAGCAAACATCG          committed neoblasts
#
#                                                   transferred  \
# L43_1_AACCATTGGAGACTAGTAACGCTCGA    pgrn+ parenchymal cells 1
# L43_1_CATTCGACGGAGATCGCACGCTGATC              chat+ neurons 1
# L43_1_ACGGAGGCGGTGGAACAATAGGATGA                  neoblasts 1
# L43_1_GACCTTGATAACGCTCGACAAGACTA  early epidermal progenitors
# L43_1_TTACCTCGACTGGAACAAAGATCGCA     intestinal and DV muscle
# ...                                                       ...
# L43_5_TAACTGGTTAAAGGTACAGAGTTAGC                    epidermis
# L43_5_GGTACCGGCAGAATCTGATGAAGAGA                  neoblasts 1
# L43_5_GCCGCAACGACCAGTTCAAGCAGGAA    pgrn+ parenchymal cells 2
# L43_5_CCAGTTCCAATGGAACAAATTGGCTC              chat+ neurons 1
# L43_5_TTCGCCTCCACAAGGAGCAAACATCG                  neoblasts 1
#
#                                        leiden_3_names_collapsed  \
# L43_1_AACCATTGGAGACTAGTAACGCTCGA      pgrn+ parenchymal cells 1
# L43_1_CATTCGACGGAGATCGCACGCTGATC                chat+ neurons 1
# L43_1_ACGGAGGCGGTGGAACAATAGGATGA                      neoblasts
# L43_1_GACCTTGATAACGCTCGACAAGACTA  early epidermal progenitors 1
# L43_1_TTACCTCGACTGGAACAAAGATCGCA       intestinal and DV muscle
# ...                                                         ...
# L43_5_TAACTGGTTAAAGGTACAGAGTTAGC                    epidermis 2
# L43_5_GGTACCGGCAGAATCTGATGAAGAGA                      neoblasts
# L43_5_GCCGCAACGACCAGTTCAAGCAGGAA      pgrn+ parenchymal cells 2
# L43_5_CCAGTTCCAATGGAACAAATTGGCTC                chat+ neurons 1
# L43_5_TTCGCCTCCACAAGGAGCAAACATCG                      neoblasts
#
#                                                  leiden_3_names  broad_names
# L43_1_AACCATTGGAGACTAGTAACGCTCGA      pgrn+ parenchymal cells 1  parenchymal
# L43_1_CATTCGACGGAGATCGCACGCTGATC                chat+ neurons 1      neurons
# L43_1_ACGGAGGCGGTGGAACAATAGGATGA                    neoblasts 1    neoblasts
# L43_1_GACCTTGATAACGCTCGACAAGACTA  early epidermal progenitors 1    epidermal
# L43_1_TTACCTCGACTGGAACAAAGATCGCA       intestinal and DV muscle       muscle
# ...                                                         ...          ...
# L43_5_TAACTGGTTAAAGGTACAGAGTTAGC                    epidermis 2    epidermal
# L43_5_GGTACCGGCAGAATCTGATGAAGAGA                    neoblasts 3    neoblasts
# L43_5_GCCGCAACGACCAGTTCAAGCAGGAA      pgrn+ parenchymal cells 2  parenchymal
# L43_5_CCAGTTCCAATGGAACAAATTGGCTC                chat+ neurons 1      neurons
# L43_5_TTCGCCTCCACAAGGAGCAAACATCG                    neoblasts 4    neoblasts
#
# [47292 rows x 23 columns]

# %% [markdown]
# # Fisher test as a function

# %% [markdown]
# Defining variables:

# %%
clusteringlayer = 'leiden_3_names_collapsed'

# %%
samples_name = 'sample'

# %%
adata.obs[samples_name].cat.categories
# Out:
# Index(['gfp(RNAi)', 'lhx1/5-1(RNAi)', 'pitx(RNAi)'], dtype='object')

# %%
s1 = 'gfp(RNAi)'
s2 = 'lhx1/5-1(RNAi)'

# %%
# Significance:
sig = 0.01

# %%
# Odd ratio:
ot = 0.25

# %% [markdown]
# Defining function:

# %%
def FisherTest (adata_in_use, clusteringlayer, samples_name, s1, s2):
    
    # Obtaining counts:
    
    cell_numbers = adata_in_use.obs[[samples_name, clusteringlayer]].groupby(samples_name)                 # Group data by samples and clusters.  
    cellcounts = {}                                                                                        # Create an empty diccionary
    for i in adata_in_use.obs[samples_name].cat.categories:                                                # For every sample (i)
        cellcounts[i] = cell_numbers.get_group(i)[clusteringlayer].value_counts().rename(i).sort_index()   # Obtain the counts per cluster
    counts_df = pd.DataFrame.from_dict(cellcounts)                                                         # Create a dataframe of counts from diccionary (cellcounts)
    
    oddsdict ={}     # Create empty dictionary for odd values
    pvalsdict = {}   # Create empty dictionary for p-values

    for j in adata_in_use.obs[clusteringlayer].cat.categories:                          # For each cluster(j)
        cl_counts = counts_df.loc[j,[s1, s2]].to_list()                                 # Obtain the counts per cluster in each sample 
        ncl_counts = (counts_df[[s1, s2]].sum() - counts_df.loc[j,[s1, s2]]).to_list()  # For each sample: total counts - counts per cluster
        oddsratio, pvalue = stats.fisher_exact([cl_counts, ncl_counts])                 # Run a fisher test to obtain the odd and p-values
        oddsdict[j] = oddsratio                                                         # Add odd ratio values to a dictionary
        pvalsdict[j] = pvalue                                                           # Add p values to a dictionary
        
    counts_dict = {}   # Create empty dictionary

    percs_df = counts_df[[s2, s1]] / counts_df[[s2, s1]].sum(axis = 0) * 100  # Calculate counts as percentage (counts per cluster / total counts * 100)
    percs_diff = percs_df[s2]-percs_df[s1]                                    # Substration of percentages between samples (creates column value % diff)
    
    fisher_test = pd.concat([pd.Series(pvalsdict),pd.Series(oddsdict), percs_diff], axis = 1, keys = ['pvals', 'odds', '% diff']) # Create a DataFrame with three columns: pval, odds and % diff    
    
    return fisher_test, counts_df, percs_df

# %% [markdown]
# # Fisher test

# %%
adata_in_use = adata

# %% [markdown]
# Running Fisher test:

# %%
fisher_test, counts_df, percs_df = FisherTest(adata_in_use, clusteringlayer, samples_name, s1, s2)

# %%
counts_df.head()
# Out:
#                           gfp(RNAi)  lhx1/5-1(RNAi)  pitx(RNAi)
# neoblasts                      3165            2542        2708
# chat+ neurons 1                1132            1154        1049
# body wall muscle                775             819         816
# intestinal and DV muscle        875             766         763
# phagocyte progenitors           899             696         789

# %%
fisher_test
# Out:
#                                pvals  odds  % diff
# neoblasts                      0.000 1.164  -2.225
# chat+ neurons 1                0.005 0.885   0.811
# body wall muscle               0.002 0.855   0.745
# intestinal and DV muscle       0.432 1.042  -0.200
# phagocyte progenitors          0.001 1.186  -0.803
# pgrn+ parenchymal cells 2      0.000 0.806   0.921
# pgrn+ parenchymal cells 1      0.000 0.778   0.976
# late epidermal progenitors     0.391 1.054  -0.188
# early epidermal progenitors 1  0.224 0.927   0.256
# phagocytes                     0.000 1.327  -0.874
# muscle pharynx                 0.204 0.911   0.223
# epidermis 1                    0.000 1.625  -1.150
# neuronal progenitors           0.881 0.988   0.028
# chat+ neurons 2                0.617 1.041  -0.085
# otf+ neurons 1                 0.001 0.762   0.484
# protonephridia flame cells     0.107 0.870   0.242
# early epidermal progenitors 2  0.014 1.256  -0.339
# celsr-1+ neurons               0.347 0.916   0.137
# th+ neurons                    0.780 0.970   0.043
# secretory 1                    0.000 1.445  -0.466
# psap+ parenchymal cells        0.101 0.845   0.201
# ldlrr+ parenchymal cells       0.057 0.827   0.251
# basal cells                    0.493 1.080  -0.087
# muscle progenitors             0.380 0.904   0.105
# epidermis 2                    0.128 0.847   0.176
# para+ neurons                  0.255 0.875   0.129
# pharynx cell type              0.821 1.027  -0.026
# secretory 2                    0.449 1.100  -0.088
# otf+ neurons 2                 0.009 0.739   0.284
# germ cell progenitors          0.003 1.387  -0.339
# pigment cells                  0.000 0.558   0.510
# protonephridia tubule cells    0.722 1.047  -0.041
# aqp+ parenchymal cells         0.000 0.638   0.358
# trpm-2-1+ neurons              0.150 0.834   0.145
# secretory 9                    0.011 1.402  -0.249
# trpa-1+ neurons                0.024 0.735   0.218
# pkd-1+ neurons                 0.715 0.939   0.037
# tinc+ neurons                  0.598 0.920   0.046
# goblet cells                   0.224 1.234  -0.099
# secretory 5                    0.067 0.729   0.143
# secretory 3                    0.395 1.165  -0.066
# tph+ neurons                   1.000 1.002  -0.001
# psd+ cells                     0.004 1.735  -0.197
# chat+ neurons 3                0.451 0.863   0.052
# epidermis DVb                  0.540 0.873   0.041
# ubc+ parenchymal cells         0.302 0.801   0.065
# gabrb-3+ neurons               0.427 0.821   0.048
# secretory 10                   0.216 1.338  -0.071
# secretory 7                    0.245 1.336  -0.066
# secretory 6                    0.168 1.397  -0.078
# secretory 11                   0.701 0.881   0.024
# secretory 8                    0.221 1.431  -0.059
# unannotated neurons            0.493 0.812   0.034
# secretory 4                    0.580 0.843   0.028
# glia                           0.053 0.552   0.082
# secretory 12                   0.880 1.092  -0.012
# pth1r+ neurons                 1.000 0.971   0.003
# unannotated 1                  0.440 0.607   0.023
# unannotated 2                  0.023 8.196  -0.047
# unannotated 3                  0.457 2.276  -0.017

# %% [markdown]
# Obtainin **UP and DOWN** regulated clusters:

# %%
# All significant clusters:
fisher_test_sig = fisher_test[fisher_test['pvals'] < sig].index.to_list()

# %%
# Clusters significantly UP and DOWN regulated:
down = (fisher_test['pvals'] < sig) & (np.log2(fisher_test['odds']) > ot)
up = (fisher_test['pvals'] < sig) & (np.log2(fisher_test['odds']) < -ot)

# %%
fisher_test[down]
# Out:
#                        pvals  odds  % diff
# phagocytes             0.000 1.327  -0.874
# epidermis 1            0.000 1.625  -1.150
# secretory 1            0.000 1.445  -0.466
# germ cell progenitors  0.003 1.387  -0.339
# psd+ cells             0.004 1.735  -0.197

# %%
fisher_test[up]
# Out:
#                            pvals  odds  % diff
# pgrn+ parenchymal cells 2  0.000 0.806   0.921
# pgrn+ parenchymal cells 1  0.000 0.778   0.976
# otf+ neurons 1             0.001 0.762   0.484
# otf+ neurons 2             0.009 0.739   0.284
# pigment cells              0.000 0.558   0.510
# aqp+ parenchymal cells     0.000 0.638   0.358

# %% [markdown]
# Saving progress:

# %%
excel_writer = pd.ExcelWriter('./outputs/fisher_test/Smed_sero_lhx_counts.xlsx', engine='xlsxwriter')

# %%
counts_df.to_excel(excel_writer, sheet_name = 'counts', index=True)
percs_df.to_excel(excel_writer, sheet_name = 'percentages', index=True)

# %%
excel_writer.save()

# %%
excel_writer = pd.ExcelWriter('./outputs/fisher_test/Smed_sero_lhx_fisher_test.xlsx', engine='xlsxwriter')

# %%
fisher_test.to_excel(excel_writer, sheet_name = 'fisher_test', index=True)
fisher_test[up].to_excel(excel_writer, sheet_name = 'UP in lhx', index=True)
fisher_test[down].to_excel(excel_writer, sheet_name = 'DOWN in lhx', index=True)

# %%
excel_writer.save()

# %% [markdown]
# # Plotting results

# %% [markdown]
# Loading final results from Fisher test

# %%
counts_adata = pd.read_excel('./outputs/fisher_test/Smed_sero_lhx_counts.xlsx', index_col = 0)

# %%
fisher_adata = pd.read_excel('./outputs/fisher_test/Smed_sero_lhx_fisher_test.xlsx', sheet_name = 'fisher_test', index_col = 0)

# %%
adata_down = pd.read_excel('./outputs/fisher_test/Smed_sero_lhx_fisher_test.xlsx', sheet_name = 'DOWN in lhx', index_col=0)
adata_up = pd.read_excel('./outputs/fisher_test/Smed_sero_lhx_fisher_test.xlsx', sheet_name = 'UP in lhx', index_col=0)

# %%
with rc_context({'figure.figsize': (10, 10)}):
    sc.pl.umap(adata, color=clusteringlayer , size = 15, frameon=False, add_outline = True)
# Out:
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:369: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:379: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sample_palette = ['#A36B2B', '#E64F72', '#2787A0']

# %%
with rc_context({'figure.figsize': (5, 5)}):
    sc.pl.umap(adata, color='sample', palette = sample_palette,  groups= 'lhx1/5-1(RNAi)', title='lhx', size = 15, frameon=False, add_outline = True, na_in_legend = False, save= '_adata_lhx.pdf')
    sc.pl.umap(adata, color='sample', palette = sample_palette, groups='gfp(RNAi)', title='gfp', size = 15, frameon=False, add_outline = True, na_in_legend = False, save= '_adata_gfp.pdf')
# Out:
# WARNING: saving figure to file figures\umap_adata_lhx.pdf
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:369: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:379: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file figures\umap_adata_gfp.pdf
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:369: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:379: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# Defining variables:

# %%
adata_in_use = adata

# %%
significants = fisher_adata[fisher_adata['pvals'] < sig].index.to_list()

# %%
significants
# Out:
# ['neoblasts',
#  'chat+ neurons 1',
#  'body wall muscle',
#  'phagocyte progenitors',
#  'pgrn+ parenchymal cells 2',
#  'pgrn+ parenchymal cells 1',
#  'phagocytes',
#  'epidermis 1',
#  'otf+ neurons 1',
#  'secretory 1',
#  'otf+ neurons 2',
#  'germ cell progenitors',
#  'pigment cells',
#  'aqp+ parenchymal cells',
#  'psd+ cells']

# %%
ft = fisher_adata

# %%
down = adata_down.index.tolist()
up = adata_up.index.tolist()

# %%
down
# Out:
# ['phagocytes',
#  'epidermis 1',
#  'secretory 1',
#  'germ cell progenitors',
#  'psd+ cells']

# %%
up
# Out:
# ['pgrn+ parenchymal cells 2',
#  'pgrn+ parenchymal cells 1',
#  'otf+ neurons 1',
#  'otf+ neurons 2',
#  'pigment cells',
#  'aqp+ parenchymal cells']

# %%
ctrl = 'gfp'
test = 'lhx'

# %% [markdown]
# ### UMAP plots for (all significants, up and down)

# %%
with plt.rc_context({'figure.figsize': (12, 12)}):
    sc.pl.umap(adata_in_use, color=clusteringlayer, legend_loc='right margin', legend_fontoutline = 5, title= test + ' vs ' + ctrl + ' (all significants)', size = 15, groups = significants, frameon=False, add_outline = False, save= '_adata_all_significants.pdf')
    sc.pl.umap(adata_in_use, color=clusteringlayer, legend_loc='right margin', legend_fontoutline = 5, title= test + ' vs ' + ctrl + ' (down in lhx)', size = 15, groups = down, na_in_legend=False, frameon=False, add_outline = False, save= '_adata_down.pdf')
    sc.pl.umap(adata_in_use, color=clusteringlayer, legend_loc='right margin', legend_fontoutline = 5, title= test + ' vs ' + ctrl + ' (up in lhx)', size = 15, groups = up, na_in_legend=False, frameon=False, add_outline = False, save= '_adata_up.pdf')
# Out:
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# WARNING: saving figure to file figures\umap_adata_all_significants.pdf
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# WARNING: saving figure to file figures\umap_adata_down.pdf
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# WARNING: saving figure to file figures\umap_adata_up.pdf
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ### Volcano plot:

# %%
max_y = abs(np.log2(ft['pvals'])).max() * 1.10          # Size limit of the y axis = maximum absolute value in column 'pvals' multiplied by a factor
max_x= abs(np.log2(ft['odds']).dropna()).max() * 1.10   # Size limit of the x axis = maximum absolute value in column 'odds' multiplied by a factor
fig, axs = plt.subplots(figsize = (7, 6))
sns.scatterplot(data = np.log2(ft), x = 'odds', y = 'pvals',
    size = adata_in_use.obs[clusteringlayer].value_counts(),
    sizes=(50, 2000),
    hue = ft.index,
    palette = list(adata_in_use.uns[clusteringlayer+'_colors']),
    legend = False,
    ax = axs)
axs.axhline(y=np.log2(sig), xmin=0, xmax=1, dashes = (2,1))
axs.axvline(x= ot, ymin=0, ymax=1, dashes = (2,1))
axs.axvline(x= -ot, ymin=0, ymax=1, dashes = (2,1))
axs.invert_yaxis()
axs.set_title(test + ' vs ' + ctrl, weight='bold')
axs.set_xlim(-(max_x), max_x)
axs.set_ylim(0,-(max_y))
axs.yaxis.set_visible(True)
axs.set_xlabel('log2 odd ratios')
axs.set_ylabel('p-values')
axs.text(.01, .99, 'Down in '+ test, ha='left', va='top')
axs.text(.99, .99, 'Up in '+ test, ha='right', va='top')
axs.grid(False)
fig.show()
fig.savefig('./outputs/fisher_test/volcano_adata.pdf')
# Out:
# C:\Users\19125778\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: invalid value encountered in log2
#   result = func(self.values, **kwargs)
# C:\Users\19125778\AppData\Local\Temp\ipykernel_14208\3855766081.py:24: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Histogram:

# %% [markdown]
# Defining plot axes:

# %%
log2_odds = pd.DataFrame(np.log2(ft['odds']))

# %%
Y_axis = log2_odds['odds'] # Plot Y-axis

# %%
index = log2_odds['odds'].index # Plot X-axis

# %%
x_pos = index # X-axis length

# %% [markdown]
# Creating plot:

# %%
fig, axs = plt.subplots(figsize=(15, 20))

axs.barh(x_pos, Y_axis, edgecolor='black', color=adata_in_use.uns[clusteringlayer+'_colors'])
axs.grid(False)
axs.axvline(x=0, color='black', linestyle='-')
axs.set_title(test + ' vs ' + ctrl)
axs.set_xlabel('Log ratio')
axs.invert_yaxis()

fig.savefig('./outputs/fisher_test/barplot_adata.pdf')

# %% [markdown]
# ### Mosaic plot :

# %%
pd.set_option('use_inf_as_na', True)

# %% [markdown]
# Creating a **map** of clusters and **colours** (to use in plot palettes):

# %%
colour_mapping = {value: color for value, color in zip(adata_in_use.obs[clusteringlayer].unique().sort_values(), adata_in_use.uns[clusteringlayer+'_colors'])}

# %% [markdown]
# Defining plot **filters**:

# %%
# Filters for plot B:

not_in_filt1 = ft[(ft['odds']==0) & (ft['% diff'] > 0)]                                 # Selects values with 0 counts in one conditions
filt1 = adata_in_use[adata_in_use.obs[clusteringlayer].isin(list(not_in_filt1.index))]  # Filters adata to clusters in previous filter
value_counts1 = filt1.obs[clusteringlayer].value_counts()                               # Extracts counts for values in previous filters

# %%
# Filters for plot D:

not_in_filt2 = ft[(ft['odds']==0) & (ft['% diff'] < 0)]  
filt2 = adata_in_use[adata_in_use.obs[clusteringlayer].isin(list(not_in_filt2.index))]            
value_counts2 = filt2.obs[clusteringlayer].value_counts()

# %% [markdown]
# Plotting figure:

# %%
# FIGURE SIZE AND DISTRIBUTION:
   
    # AAAAEEE etc: Profiles the spatial distribution of plots labeled as A, B, C, D and E. 

fig = plt.figure(figsize=(12, 10))
axd = fig.subplot_mosaic(
    """
    AAAAEEEE
    AAAAEEEE
    AAAAEEEE
    AAAAEEEE
    BCCCCCCD
    BCCCCCCD
    """)

# DEFINITION OF AXES (axd):

max_y = abs(np.log2(ft['pvals'])).max() * 1.10          # Size limit of the y axis = maximum absolute value in column 'pvals' multiplied by a factor
max_x= abs(np.log2(ft['odds']).dropna()).max() * 1.10   # Size limit of the x axis = maximum absolute value in column 'odds' multiplied by a factor

# PLOT A: CLUSTERS UP

sc.pl.umap(adata_in_use, color=clusteringlayer, legend_loc='on data', legend_fontoutline = 5, title= 'Up in '+ test,
    size = 15, groups = up, na_in_legend=False, frameon=False, show = False, 
    ax = axd['A'])

# PLOT B: CLUSTERS NOT IN CTRL

sns.scatterplot(data = np.log2(not_in_filt1), x = 0, y = 'pvals',                       # Defines data and values in axes.
    size = value_counts1,                                                               # Cluster (dots) sizes are proportionate to their number of counts
    sizes = (50,400),                                                                   # Size of the smallest and biggest clusters (dots)
    hue = not_in_filt1.index,
    palette = [colour_mapping[value] for value in list(not_in_filt1.index.to_list())],
    legend = False,
    ax = axd['B'])
axd['B'].axhline(y=np.log2(sig), xmin=0, xmax=1, dashes = (2,1))
axd['B'].invert_yaxis()
axd['B'].set_title("not in " + ctrl)
axd['B'].set_ylim(0,-(max_y))
axd['B'].xaxis.set_visible(False)
axd['B'].set_ylabel('p-values')
axd['B'].grid(False)

# PLOT C: VOLCANO PLOT OF UP AND DOWN CLUSTERS

sns.scatterplot(data = np.log2(ft), x = 'odds', y = 'pvals',         # Defines data (log2) and values in axes.
    size = adata_in_use.obs[clusteringlayer].value_counts(),         # Cluster (dots) sizes are proportionate to their number of counts
    sizes=(50,400),                                                  # Size of the smallest and biggest clusters (dots)
    hue = ft.index,                                                  # Indicates what gets coloured (cluster names)
    palette = list(adata_in_use.uns[clusteringlayer+'_colors']),     # List of colours to use in the plot
    legend = False,                                                  # No legend in volcano plot
    ax = axd['C'])                                                   # Plot label
axd['C'].axhline(y=np.log2(sig), xmin=0, xmax=1, dashes = (2,1))     # Traces line in y-axis where y equals the logarithm of p-value (sig)
axd['C'].axvline(x= ot, ymin=0, ymax=1, dashes = (2,1))
axd['C'].axvline(x=-ot, ymin=0, ymax=1, dashes = (2,1))
axd['C'].invert_yaxis()
axd['C'].set_title('Fisher exact test ' + test + ' against ' + ctrl, weight="bold")
axd['C'].set_xlim(-(max_x), max_x)
axd['C'].set_ylim(0,-(max_y))
axd['C'].yaxis.set_visible(False)
axd['C'].set_xlabel('log2 odd ratios')
axd['C'].text(.01, .99, 'Up in '+ test, ha='left', va='top', transform=axd['C'].transAxes)
axd['C'].text(.99, .99, 'Down in '+ test, ha='right', va='top', transform=axd['C'].transAxes)
axd['C'].grid(False)

# PLOT D: CLUSTERS NOT IN TEST

sns.scatterplot(data = np.log2(not_in_filt2), x = 0, y = 'pvals', 
    size = value_counts2,
    sizes = (50, 400),
    hue = not_in_filt2.index,
    palette = [colour_mapping[value] for value in list(not_in_filt2.index.to_list())],
    legend = False,
    ax = axd['D'])
axd['D'].axhline(y=np.log2(sig), xmin=0, xmax=1, dashes = (2,1))
axd['D'].invert_yaxis()
axd['D'].set_title("not in "+ test)
axd['D'].set_ylim(0,-(max_y))
axd['D'].xaxis.set_visible(False)
axd['D'].yaxis.set_visible(False)
axd['D'].grid(False)

# PLOT E: CLUSTERS DOWN

sc.pl.umap(adata_in_use, color=clusteringlayer, legend_loc='on data', legend_fontoutline = 5, title= 'Down in '+ test,
        size = 15, groups = down, na_in_legend=False, frameon=False, show = False, 
        ax = axd['E'])

fig.savefig('./outputs/fisher_test/mosaic_adata.pdf')
# Out:
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\19125778\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: invalid value encountered in log2
#   result = func(self.values, **kwargs)
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1171: FutureWarning: Categorical.replace is deprecated and will be removed in a future version. Use Series.replace directly instead.
#   values = values.replace(values.categories.difference(groups), np.nan)
# C:\Users\19125778\Anaconda3\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
